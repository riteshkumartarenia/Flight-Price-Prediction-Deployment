# %% [markdown]
# # Importing Libraries

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # Importing Train_Data

# %%
train = pd.read_excel('/content/drive/MyDrive/Dataset/Data_Train.xlsx')
train
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
train.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
train.tail()
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 10678              CCU → BLR    19:55        22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45        23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20        11:20       3h    non-stop
# 10681              BLR → DEL    11:30        14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55        19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753

# %% [markdown]
# # Data Cleaning

# %%
train.shape
# Out:
# (10683, 11)

# %%
column_train = train.columns
column_train
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
train.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
train.dropna(inplace=True)

# %%
duplicate = train[train.duplicated()]
duplicate
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 683    Jet Airways       1/06/2019     Delhi      Cochin
# 1061     Air India      21/05/2019     Delhi      Cochin
# 1348     Air India      18/05/2019     Delhi      Cochin
# 1418   Jet Airways       6/06/2019     Delhi      Cochin
# 1674        IndiGo      24/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10594  Jet Airways      27/06/2019     Delhi      Cochin
# 10616  Jet Airways       1/06/2019     Delhi      Cochin
# 10634  Jet Airways       6/06/2019     Delhi      Cochin
# 10672  Jet Airways      27/06/2019     Delhi      Cochin
# 10673  Jet Airways      27/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 683    DEL → NAG → BOM → COK    14:35  04:25 02 Jun  13h 50m     2 stops
# 1061   DEL → GOI → BOM → COK    22:00  19:15 22 May  21h 15m     2 stops
# ...

# %%
train.drop_duplicates(inplace=True)

# %%
#pd.set_option('display.max_columns', None)

# %%
train.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
# Extracting Journey
train['Journey_Day'] = pd.to_datetime(train['Date_of_Journey'],format='%d/%m/%Y').dt.day
train['Journey_Month'] = pd.to_datetime(train['Date_of_Journey'], format= "%d/%m/%Y").dt.month

# %%
#pd.to_datetime(train['Date_of_Journey'],format='%d/%m/%Y').dt.year.value_counts()

# %%
# Extracting Dep_Time
train['Dep_Hour'] = pd.to_datetime(train['Dep_Time']).dt.hour
train['Dep_Min'] = pd.to_datetime(train['Dep_Time']).dt.minute

# %%
# Extracting Arrival_Time
train['Arrival_Hour'] = pd.to_datetime(train['Arrival_Time']).dt.hour
train['Arrival_Min'] = pd.to_datetime(train['Arrival_Time']).dt.minute

# %%
duration = list(train['Duration'])

for i in range(len(duration)):
  if len(duration[i].split())!=2:
    if 'h' in duration[i]:
      duration[i] = duration[i].strip()+' 0m'
    else:
      duration[i] = '0h ' + duration[i] 

duration_hours = []
duration_min = []

for i in range(len(duration)):
  duration_hours.append(int(duration[i].split(sep='h')[0]))
  duration_min.append(int(duration[i].split(sep='m')[0].split()[-1]))

# %%
train['Duration_hours'] = duration_hours
train['Duration_mins'] = duration_min

# %%
train.drop(['Date_of_Journey','Dep_Time','Arrival_Time','Duration','Route','Additional_Info'],axis=1,inplace=True)

# %%
train.Total_Stops.value_counts()
# Out:
# 1 stop      5625
# non-stop    3475
# 2 stops     1318
# 3 stops       43
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %%
train.replace({'non-stop': 0, '1 stop' : 1 , '2 stops' : 2, '3 stops' : 3 , '4 stops':4},inplace=True)

# %%
train.head()
# Out:
#        Airline    Source Destination  Total_Stops  Price  Journey_Day  \
# 0       IndiGo  Banglore   New Delhi            0   3897           24
# 1    Air India   Kolkata    Banglore            2   7662            1
# 2  Jet Airways     Delhi      Cochin            2  13882            9
# 3       IndiGo   Kolkata    Banglore            1   6218           12
# 4       IndiGo  Banglore   New Delhi            1  13302            1
#
#    Journey_Month  Dep_Hour  Dep_Min  Arrival_Hour  Arrival_Min  \
# 0              3        22       20             1           10
# 1              5         5       50            13           15
# 2              6         9       25             4           25
# 3              5        18        5            23           30
# 4              3        16       50            21           35
#
#    Duration_hours  Duration_mins
# 0               2             50
# 1               7             25
# 2              19              0
# ...

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=train['Airline'])
plt.xticks(rotation=90,fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x=train['Source'])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x=train['Destination'])
plt.show()

# %%
train['Total_Stops'].value_counts().plot(kind='pie',autopct='%.2f%%')
plt.show()

# %%
sns.boxplot(x=train['Price'])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.displot(x='Price',data=train,kde=True,color='g')
plt.show()

# %%
train.groupby('Airline')['Price'].max().plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.boxplot(y = "Price", x = "Airline", data = train.sort_values("Price", ascending = False))
plt.xticks(rotation=90,fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(y = "Price", x = "Source", data = train.sort_values("Price", ascending = False))
plt.xticks(rotation=45,fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(y = "Price", x = "Destination", data = train.sort_values("Price", ascending = False))
plt.xticks(rotation=45,fontsize=12)
plt.show()

# %%
sns.catplot(y = "Price", x = "Airline", data = train.sort_values("Price", ascending = False), kind="boxen", height = 6, aspect = 3)
plt.show()

# %%
sns.catplot(y = "Price", x = "Source", data = train.sort_values("Price", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
sns.catplot(y = "Price", x = "Destination", data = train.sort_values("Price", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()

# %%
train.corr()
# Out:
#                 Total_Stops     Price  Journey_Day  Journey_Month  Dep_Hour  \
# Total_Stops        1.000000  0.602013    -0.018937       0.039003 -0.067523
# Price              0.602013  1.000000    -0.159044      -0.113396  0.005155
# Journey_Day       -0.018937 -0.159044     1.000000      -0.038331 -0.003394
# Journey_Month      0.039003 -0.113396    -0.038331       1.000000  0.040406
# Dep_Hour          -0.067523  0.005155    -0.003394       0.040406  1.000000
# Dep_Min           -0.002695 -0.024155    -0.004741      -0.062636 -0.015068
# Arrival_Hour       0.051476  0.031023    -0.002448       0.001423 -0.003827
# Arrival_Min       -0.107099 -0.086163    -0.015086      -0.099261  0.072989
# Duration_hours     0.730156  0.504200    -0.029382       0.006410 -0.000648
# Duration_mins     -0.150253 -0.131664    -0.009244      -0.046325 -0.018843
#
#                  Dep_Min  Arrival_Hour  Arrival_Min  Duration_hours  \
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(train.corr(),annot=True,linewidth=5,cmap='viridis')
plt.show()

# %% [markdown]
# # Machine Learning Algorithm for Train_Data

# %%
train.head()
# Out:
#        Airline    Source Destination  Total_Stops  Price  Journey_Day  \
# 0       IndiGo  Banglore   New Delhi            0   3897           24
# 1    Air India   Kolkata    Banglore            2   7662            1
# 2  Jet Airways     Delhi      Cochin            2  13882            9
# 3       IndiGo   Kolkata    Banglore            1   6218           12
# 4       IndiGo  Banglore   New Delhi            1  13302            1
#
#    Journey_Month  Dep_Hour  Dep_Min  Arrival_Hour  Arrival_Min  \
# 0              3        22       20             1           10
# 1              5         5       50            13           15
# 2              6         9       25             4           25
# 3              5        18        5            23           30
# 4              3        16       50            21           35
#
#    Duration_hours  Duration_mins
# 0               2             50
# 1               7             25
# 2              19              0
# ...

# %%
train['Airline'].value_counts()
# Out:
# Jet Airways                          3700
# IndiGo                               2043
# Air India                            1694
# Multiple carriers                    1196
# SpiceJet                              815
# Vistara                               478
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64

# %%
train['Source'].value_counts()
# Out:
# Delhi       4345
# Kolkata     2860
# Banglore    2179
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64

# %%
train['Destination'].value_counts()
# Out:
# Cochin       4345
# Banglore     2860
# Delhi        1265
# New Delhi     914
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64

# %%
# Data Preprocessing
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
train['Airline'] = le.fit_transform(train['Airline']) 
train['Source'] = le.fit_transform(train['Source'])
train['Destination'] = le.fit_transform(train['Destination'])

# %%
train.head()
# Out:
#    Airline  Source  Destination  Total_Stops  Price  Journey_Day  \
# 0        3       0            5            0   3897           24
# 1        1       3            0            2   7662            1
# 2        4       2            1            2  13882            9
# 3        3       3            0            1   6218           12
# 4        3       0            5            1  13302            1
#
#    Journey_Month  Dep_Hour  Dep_Min  Arrival_Hour  Arrival_Min  \
# 0              3        22       20             1           10
# 1              5         5       50            13           15
# 2              6         9       25             4           25
# 3              5        18        5            23           30
# 4              3        16       50            21           35
#
#    Duration_hours  Duration_mins
# 0               2             50
# 1               7             25
# 2              19              0
# 3               5             25
# ...

# %%
train['Airline'].value_counts()
# Out:
# 4     3700
# 3     2043
# 1     1694
# 6     1196
# 8      815
# 10     478
# 0      319
# 2      194
# 7       13
# 5        6
# 11       3
# 9        1
# Name: Airline, dtype: int64

# %%
train['Source'].value_counts()
# Out:
# 2    4345
# 3    2860
# 0    2179
# 4     697
# 1     381
# Name: Source, dtype: int64

# %%
train['Destination'].value_counts()
# Out:
# 1    4345
# 0    2860
# 2    1265
# 5     914
# 3     697
# 4     381
# Name: Destination, dtype: int64

# %%
x = train.drop(['Price'],axis=1)
y= train.loc[:,['Price']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=10)

# %%
# model building
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
model_lr = LinearRegression()
model_kn = KNeighborsRegressor(n_neighbors=100)
model_svr = SVR()
model_dtr = DecisionTreeRegressor()
model_rfr = RandomForestRegressor()

# %%
# Fitting Process & predicting
rmodels = [model_lr,model_kn,model_svr,model_dtr,model_rfr]

for rgs in rmodels:
    rgs.fit(x_train,y_train)
    print(rgs)
    if rgs == model_lr:
        pred_lr = rgs.predict(x_test)
    elif rgs== model_kn:
        pred_kn = rgs.predict(x_test)     
    elif rgs == model_svr:
        pred_svr = rgs.predict(x_test)
    elif rgs == model_dtr:
        pred_dtr = rgs.predict(x_test)
    elif rgs == model_rfr:
        pred_rfr = rgs.predict(x_test)
# Out:
# LinearRegression()
# KNeighborsRegressor(n_neighbors=100)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()
# DecisionTreeRegressor()
# <ipython-input-54-c7799384bb2c>:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rgs.fit(x_train,y_train)
# RandomForestRegressor()

# %%
# check MSE , r2_score
from sklearn.metrics import mean_squared_error,r2_score

# %%
pred_mod = ['pred_lr','pred_kn','pred_svr','pred_dtr','pred_rfr']

for y_pred in pred_mod:
    if y_pred == 'pred_lr':
      print("Accuracy for Linear Regression:",r2_score(y_test,pred_lr))
      print('Error for Linear Regression:',mean_squared_error(y_test,pred_lr))
      print('')
    elif y_pred == 'pred_kn':
      print("Accuracy for K Neighbors Regression:",r2_score(y_test,pred_kn))
      print('Error for K Neighbors Regression:',mean_squared_error(y_test,pred_kn))
      print('')
    elif y_pred == 'pred_svr':
      print(" Accuracy of SVR:",r2_score(y_test,pred_svr))
      print('Error for SVR:',mean_squared_error(y_test,pred_svr))
      print('')
    elif y_pred == 'pred_dtr':
      print(" Accuracy of Decision Tree:",r2_score(y_test,pred_dtr))
      print('Error for Decision Tree:',mean_squared_error(y_test,pred_dtr))
      print('')
    elif y_pred == 'pred_rfr':
      print(" Accuracy of Random Forest:",r2_score(y_test,pred_rfr))
      print('Error for Random FOrest:',mean_squared_error(y_test,pred_rfr))
# Out:
# Accuracy for Linear Regression: 0.447256322231796
# Error for Linear Regression: 11367948.070528245
#
# Accuracy for K Neighbors Regression: 0.36705952101161865
# Error for K Neighbors Regression: 13017307.635117903
#
#  Accuracy of SVR: 0.0002941085393741716
# Error for SVR: 20560352.1433516
#
#  Accuracy of Decision Tree: 0.6771482206829909
# Error for Decision Tree: 6639899.123898269
#
#  Accuracy of Random Forest: 0.8210330904505625
# Error for Random FOrest: 3680705.209176726

# %%
pd.DataFrame(zip(pred_lr.flatten(), pred_kn.flatten(),pred_svr,pred_dtr,pred_rfr  ),columns =['Train_Linear','Train_Knn','Train_SVM','Train_DecisionTree','Train_RandomForest'])
# Out:
#       Train_Linear  Train_Knn    Train_SVM  Train_DecisionTree  \
# 0      8560.601204    9010.49  8128.958730             12488.0
# 1      7162.866342    5594.58  8074.081795              6857.0
# 2      8614.577039    7775.24  8259.180883             13377.0
# 3      9937.435598   12304.99  8290.754130             14571.0
# 4     15575.380831   11346.16  8227.507096             12778.0
# ...            ...        ...          ...                 ...
# 3134   9592.680365    7694.38  8273.253907             12373.0
# 3135  12197.245397   10323.38  8363.777183             14053.0
# 3136  11193.607694   11320.95  8420.221177              4588.0
# 3137  11280.146959   11105.89  8487.270059             13067.0
# 3138   7063.937645    6483.92  8108.371826              7229.0
#
#       Train_RandomForest
# 0           12534.307000
# 1            6045.850000
# 2           11308.640000
# 3           13431.809167
# 4           12348.180000
# ...                  ...
# ...

# %% [markdown]
# # Importing Test_Data

# %%
test = pd.read_excel('/content/drive/MyDrive/Dataset/Test_set.xlsx')
test
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL → BOM → COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU → MAA → BLR    06:20         10:20       4h      1 stop
# ...

# %%
test.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
test.shape
# Out:
# (2671, 10)

# %%
print("Test data Info")
print("-"*75)
print(test.info())
# Out:
# Test data Info
# ---------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2671 entries, 0 to 2670
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          2671 non-null   object
#  1   Date_of_Journey  2671 non-null   object
#  2   Source           2671 non-null   object
#  3   Destination      2671 non-null   object
#  4   Route            2671 non-null   object
#  5   Dep_Time         2671 non-null   object
#  6   Arrival_Time     2671 non-null   object
#  7   Duration         2671 non-null   object
#  8   Total_Stops      2671 non-null   object
#  9   Additional_Info  2671 non-null   object
# dtypes: object(10)
# memory usage: 208.8+ KB
# None

# %%
print("Null values :")
print("-"*75)
print(test.isnull().sum())
test.dropna(inplace = True)
print("-"*75)
print(test.isnull().sum())
# Out:
# Null values :
# ---------------------------------------------------------------------------
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# dtype: int64
# ---------------------------------------------------------------------------
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# dtype: int64

# %%
# Extracting Date_of_Journey
test["Journey_day"] = pd.to_datetime(test.Date_of_Journey, format="%d/%m/%Y").dt.day
test["Journey_month"] = pd.to_datetime(test["Date_of_Journey"], format = "%d/%m/%Y").dt.month
test.drop(["Date_of_Journey"], axis = 1, inplace = True)

# %%
# Extracting Dep_Time
test["Dep_hour"] = pd.to_datetime(test["Dep_Time"]).dt.hour
test["Dep_min"] = pd.to_datetime(test["Dep_Time"]).dt.minute
test.drop(["Dep_Time"], axis = 1, inplace = True)

# %%
# Extracting Arrival_Time
test["Arrival_hour"] = pd.to_datetime(test.Arrival_Time).dt.hour
test["Arrival_min"] = pd.to_datetime(test.Arrival_Time).dt.minute
test.drop(["Arrival_Time"], axis = 1, inplace = True)

# %%
# Duration
duration = list(test["Duration"])

for i in range(len(duration)):
    if len(duration[i].split()) != 2:    # Check if duration contains only hour or mins
        if "h" in duration[i]:
            duration[i] = duration[i].strip() + " 0m"   # Adds 0 minute
        else:
            duration[i] = "0h " + duration[i]           # Adds 0 hour

duration_hours = []
duration_mins = []
for i in range(len(duration)):
    duration_hours.append(int(duration[i].split(sep = "h")[0]))    # Extract hours from duration
    duration_mins.append(int(duration[i].split(sep = "m")[0].split()[-1]))   # Extracts only minutes from duration

# %%
# Adding Duration column to test set
test["Duration_hours"] = duration_hours
test["Duration_mins"] = duration_mins
test.drop(["Duration"], axis = 1, inplace = True)

# %%
# Replacing Total_Stops
test.replace({"non-stop": 0, "1 stop": 1, "2 stops": 2, "3 stops": 3, "4 stops": 4}, inplace = True)

# %%
test.drop(["Route", "Additional_Info"], axis = 1, inplace = True)

# %%
# Data Preprocessing
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
test['Airline'] = le.fit_transform(test['Airline']) 
test['Source'] = le.fit_transform(test['Source'])
test['Destination'] = le.fit_transform(test['Destination'])

# %%
test.head()
# Out:
#    Airline  Source  Destination  Total_Stops  Journey_day  Journey_month  \
# 0        4       2            1            1            6              6
# 1        3       3            0            1           12              5
# 2        4       2            1            1           21              5
# 3        6       2            1            1           21              5
# 4        0       0            2            0           24              6
#
#    Dep_hour  Dep_min  Arrival_hour  Arrival_min  Duration_hours  Duration_mins
# 0        17       30             4           25              10             55
# 1         6       20            10           20               4              0
# 2        19       15            19            0              23             45
# 3         8        0            21            0              13              0
# 4        23       55             2           45               2             50

# %%
x.shape
# Out:
# (10462, 12)

# %%
y.shape
# Out:
# (10462, 1)

# %%
test.shape
# Out:
# (2671, 12)

# %%
x
# Out:
#        Airline  Source  Destination  Total_Stops  Journey_Day  Journey_Month  \
# 0            3       0            5            0           24              3
# 1            1       3            0            2            1              5
# 2            4       2            1            2            9              6
# 3            3       3            0            1           12              5
# 4            3       0            5            1            1              3
# ...        ...     ...          ...          ...          ...            ...
# 10678        0       3            0            0            9              4
# 10679        1       3            0            0           27              4
# 10680        4       0            2            0           27              4
# 10681       10       0            5            0            1              3
# 10682        1       2            1            2            9              5
#
# ...

# %%
y
# Out:
#        Price
# 0       3897
# 1       7662
# 2      13882
# 3       6218
# 4      13302
# ...      ...
# 10678   4107
# 10679   4145
# 10680   7229
# 10681  12648
# 10682  11753
#
# [10462 rows x 1 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=10)

# %%
lr = LinearRegression()
knn = KNeighborsRegressor(n_neighbors=100)
svr = SVR()
dt = DecisionTreeRegressor()
rt = RandomForestRegressor()

# %%
model = [lr,knn,svr,dt,rt]
for i in model:
  i.fit(x,y)
  print(i)
  if i == lr:
      test_lr = i.predict(test)
  elif i== knn:
    test_kn = i.predict(test)     
  elif i == svr:
    test_svr = i.predict(test)
  elif i == dt:
    test_dtr = i.predict(test)
  elif i == rt:
    test_rfr = i.predict(test)
# Out:
# LinearRegression()
# KNeighborsRegressor(n_neighbors=100)
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Arrival_hour
# - Arrival_min
# - Dep_hour
# - Dep_min
# - Journey_day
# - ...
# Feature names seen at fit time, yet now missing:
# - Arrival_Hour
# - Arrival_Min
# - Dep_Hour
# - Dep_Min
# - Journey_Day
# - ...
#
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Arrival_hour
# - Arrival_min
# - Dep_hour
# - Dep_min
# - Journey_day
# - ...
# Feature names seen at fit time, yet now missing:
# - Arrival_Hour
# - Arrival_Min
# - Dep_Hour
# - Dep_Min
# - Journey_Day
# - ...
#
# ...

# %%
# pred_mod = ['test_lr','test_kn','test_svr','test_dtr','test_rfr']

# for y_pred in pred_mod:
#     if y_pred == 'test_lr':
#       print("Accuracy for Linear Regression:",r2_score(test,test_lr))
#       print('Error for Linear Regression:',mean_squared_error(test,test_lr))
#       print('')
#     elif y_pred == 'test_kn':
#       print("Accuracy for K Neighbors Regression:",r2_score(test,test_kn))
#       print('Error for K Neighbors Regression:',mean_squared_error(test,test_kn))
#       print('')
#     elif y_pred == 'test_svr':
#       print(" Accuracy of SVR:",r2_score(test,test_svr))
#       print('Error for SVR:',mean_squared_error(test,test_svr))
#       print('')
#     elif y_pred == 'test_dtr':
#       print(" Accuracy of Decision Tree:",r2_score(test,test_dtr))
#       print('Error for Decision Tree:',mean_squared_error(test,test_dtr))
#       print('')
#     elif y_pred == 'test_rfr':
#       print(" Accuracy of Random Forest:",r2_score(test,test_rfr))
#       print('Error for Random FOrest:',mean_squared_error(test,test_rfr))

# %% [markdown]
# # Save

# %%
round(prediction[0], 1)

# %%
round(10942.903333,1)
# Out:
# 10942.9

# %%
pd.DataFrame(zip(test_rfr),columns =['Test_RandomForest'])
# Out:
#       Test_RandomForest
# 0          10942.903333
# 1           4226.000000
# 2          14286.690857
# 3          12678.103333
# 4           3721.700000
# ...                 ...
# 2666       10259.700000
# 2667        4884.268000
# 2668       14218.843167
# 2669       15025.050000
# 2670        7442.720000
#
# [2671 rows x 1 columns]

# %%
df = pd.DataFrame(test_rfr)
df
# Out:
#                  0
# 0     10942.903333
# 1      4226.000000
# 2     14286.690857
# 3     12678.103333
# 4      3721.700000
# ...            ...
# 2666  10259.700000
# 2667   4884.268000
# 2668  14218.843167
# 2669  15025.050000
# 2670   7442.720000
#
# [2671 rows x 1 columns]

# %%
#df.to_excel('/content/drive/MyDrive/Dataset/example.xlsx',index=False)

# %% [markdown]
# # save 2

# %%
train
# Out:
#        Airline  Source  Destination  Total_Stops  Price  Journey_Day  \
# 0            3       0            5            0   3897           24
# 1            1       3            0            2   7662            1
# 2            4       2            1            2  13882            9
# 3            3       3            0            1   6218           12
# 4            3       0            5            1  13302            1
# ...        ...     ...          ...          ...    ...          ...
# 10678        0       3            0            0   4107            9
# 10679        1       3            0            0   4145           27
# 10680        4       0            2            0   7229           27
# 10681       10       0            5            0  12648            1
# 10682        1       2            1            2  11753            9
#
#        Journey_Month  Dep_Hour  Dep_Min  Arrival_Hour  Arrival_Min  \
# 0                  3        22       20             1           10
# ...

# %%
deploy_df = train

# %%
deploy_df.to_csv('/content/drive/MyDrive/Dataset/deploy_df.csv')

# %%
pd.read_csv('/content/drive/MyDrive/Dataset/deploy_df.csv')
# Out:
#        Unnamed: 0  Airline  Source  Destination  Total_Stops  Price  \
# 0               0        3       0            5            0   3897
# 1               1        1       3            0            2   7662
# 2               2        4       2            1            2  13882
# 3               3        3       3            0            1   6218
# 4               4        3       0            5            1  13302
# ...           ...      ...     ...          ...          ...    ...
# 10457       10678        0       3            0            0   4107
# 10458       10679        1       3            0            0   4145
# 10459       10680        4       0            2            0   7229
# 10460       10681       10       0            5            0  12648
# 10461       10682        1       2            1            2  11753
#
#        Journey_Day  Journey_Month  Dep_Hour  Dep_Min  Arrival_Hour  \
# 0               24              3        22       20             1
# ...

# %%
train.head()
# Out:
#    Airline  Source  Destination  Total_Stops  Price  Journey_Day  \
# 0        3       0            5            0   3897           24
# 1        1       3            0            2   7662            1
# 2        4       2            1            2  13882            9
# 3        3       3            0            1   6218           12
# 4        3       0            5            1  13302            1
#
#    Journey_Month  Dep_Hour  Dep_Min  Arrival_Hour  Arrival_Min  \
# 0              3        22       20             1           10
# 1              5         5       50            13           15
# 2              6         9       25             4           25
# 3              5        18        5            23           30
# 4              3        16       50            21           35
#
#    Duration_hours  Duration_mins
# 0               2             50
# 1               7             25
# 2              19              0
# 3               5             25
# ...

# %%
train['Airline'].value_counts()
# Out:
# 4     3700
# 3     2043
# 1     1694
# 6     1196
# 8      815
# 10     478
# 0      319
# 2      194
# 7       13
# 5        6
# 11       3
# 9        1
# Name: Airline, dtype: int64
